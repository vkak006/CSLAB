# %%
import tensorflow as tf
import os
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import csv
import readData
PH = 60
category = 'epoch300'
datapath = 'data/sch'

filename = os.listdir(datapath)
train_data_name = []
test_data_name = []

for fn in filename:
    if fn.find("test") != -1:
        test_data_name.append(fn)
    elif fn.find("train") != -1:
        train_data_name.append(fn)
        
print(train_data_name)
A1cList = []
A1c_train = []
A1c_test = []

total_x_data = []
total_y_data = []        

test_x_data = []
test_y_data = []
train_x_data = []
train_y_data = []

for fn in train_data_name:
    x,y,A1c,DM,BMI,age,AD = readData.readData(datapath+"/"+str(fn), PH)
    train_x_data.append(x)
    total_x_data.append(x)
    train_y_data.append(y)
    total_y_data.append(y)
    A1cList.append(A1c)
    A1c_train.append(A1c)
    print(fn)

for fn in test_data_name:
    x,y,A1c,DM,BMI,age,AD = readData.readData(datapath+"/"+str(fn), PH)
    test_x_data.append(x)
    #total_x_data.append(x)
    test_y_data.append(y)
    #total_y_data.append(y)
    #A1cList.append(A1c)
    A1c_test.append(A1c)
    print(fn)
# Out:
# import readData complete
# ['822250_train.csv', '209019_train.csv', '85655_train.csv', '579883_train.csv', '839654_train.csv', '1393413_train.csv']
# 822250_train.csv
# 209019_train.csv
# 85655_train.csv
# 579883_train.csv
# 839654_train.csv
# 1393413_train.csv
# 1185429_test.csv
# 553778_test.csv
# 920087_test.csv

# %%
X = tf.placeholder(tf.float32,shape=[None,7,1])
Y = tf.placeholder(tf.float32,shape=[None,1])

'''
W = tf.Variable(tf.random_uniform([1,15], minval = -1, maxval = 1, dtype = tf.float32))
b = tf.Variable(tf.zeros([1,15],dtype = tf.float32))

W1 = tf.Variable(tf.random_uniform([15,1], minval = -1, maxval = 1, dtype = tf.float32))
b1 = tf.Variable(tf.zeros([1,1],dtype = tf.float32))'''

cell = tf.contrib.rnn.BasicLSTMCell(num_units=20,state_is_tuple=True,activation=tf.tanh)
outputs, _states = tf.nn.dynamic_rnn(cell,X,dtype=tf.float32)

Y_p = tf.contrib.layers.fully_connected(outputs[:,-1],64,activation_fn=None)
Y_p2 = tf.contrib.layers.fully_connected(Y_p,10,activation_fn=None)
O1 = tf.contrib.layers.fully_connected(Y_p2,1,activation_fn=None)

save_file = './PH60_pretrain.ckpt'
saver = tf.train.Saver()

A1c = tf.placeholder(tf.float32,shape=[None,1])
Y_A = tf.contrib.layers.fully_connected(A1c,10,activation_fn=tf.sigmoid)
O2 = tf.contrib.layers.fully_connected(Y_A,1,activation_fn=tf.sigmoid)
#Y_pr = tf.contrib.layers.fully_connected(Y_p+Y_A,1,activation_fn=None)
Y_pr = tf.contrib.layers.fully_connected(O1+O2,15,activation_fn=None)

Y_pre =  tf.contrib.layers.fully_connected(Y_pr,1,activation_fn=None)

rmse = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(Y, Y_pre))))
loss = tf.reduce_sum(tf.square(Y_pre - Y))
optimizer = tf.train.AdamOptimizer(learning_rate = 0.01)
train = optimizer.minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())
saver.restore(sess, save_file)
for loop in range(len(total_x_data)):
    for i in  range(300):
        sess.run(train,feed_dict = {X:train_x_data[loop],Y:train_y_data[loop],A1c:A1cList[loop]})
        #sess.run(train,feed_dict = {X:total_x_data[loop],Y:total_y_data[loop]})
    print(str(loop / len(total_x_data) * 100) + "%")

print("Learning Complete!")
# Out:
# WARNING:tensorflow:From <ipython-input-2-317d8b461633>:11: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# INFO:tensorflow:Restoring parameters from ./PH60_pretrain.ckpt
# 0.0%
# 16.666666666666664%
# 33.33333333333333%
# 50.0%
# 66.66666666666666%
# 83.33333333333334%
# Learning Complete!

# %%
pre_List = []
for loop in range(len(test_x_data)):
    for i,k in enumerate(test_x_data[0]):
        ln = sess.run(Y_pre,feed_dict={X:[k],A1c:A1c_test[0]})
        #print("실제혈당 : "+str(test_y_data[0][i])+"예측혈당 : "+str(ln[0][0]))
        pre_List.append(ln[0][0])
        #print([sess.run(Y_p,feed_dict={X:[k]})[0][0],10.0])
    break;

print("loop end")

rmse_total = 0.0
rmse_one = 0.0
total_num = 0
one_person_num = 0
for size in range(len(test_x_data)):
    one_person_num = 0
    rmse_one = 0
    for i,k in enumerate(test_x_data[size]):
        total_num += 1
        one_person_num += 1
        #print(sess.run(rmse,feed_dict={X:[k],Y:[test_y_data[size][i]],A1c:[A1c_test[size][i]],G:[glucose_test[size][i]]}))
        tmp = sess.run(rmse,feed_dict={X:[k],Y:[test_y_data[size][i]],A1c:[A1c_test[size][i]]})
        rmse_total += tmp
        rmse_one += tmp
    #print(str(size+1)+"번째 환자 rmse : "+str(rmse_one/float(one_person_num)))

rmse_total = rmse_total / float(total_num)
print("전체 평균 rmse : "+str(rmse_total))

plt.plot(pre_List,color="red")
plt.plot(test_y_data[0],color="blue")
plt.show()
# Out:
# 실제혈당 : [ 157.]예측혈당 : 160.963
# 실제혈당 : [ 163.]예측혈당 : 159.737
# 실제혈당 : [ 175.]예측혈당 : 158.725
# 실제혈당 : [ 180.]예측혈당 : 160.52
# 실제혈당 : [ 184.]예측혈당 : 162.961
# 실제혈당 : [ 189.]예측혈당 : 170.707
# 실제혈당 : [ 191.]예측혈당 : 169.175
# 실제혈당 : [ 195.]예측혈당 : 167.657
# 실제혈당 : [ 201.]예측혈당 : 165.657
# 실제혈당 : [ 206.]예측혈당 : 165.566
# 실제혈당 : [ 210.]예측혈당 : 165.588
# 실제혈당 : [ 214.]예측혈당 : 167.351
# 실제혈당 : [ 216.]예측혈당 : 165.73
# 실제혈당 : [ 202.]예측혈당 : 167.936
# 실제혈당 : [ 195.]예측혈당 : 171.388
# 실제혈당 : [ 187.]예측혈당 : 180.164
# 실제혈당 : [ 167.]예측혈당 : 181.444
# 실제혈당 : [ 177.]예측혈당 : 184.937
# 실제혈당 : [ 184.]예측혈당 : 188.784
# 실제혈당 : [ 188.]예측혈당 : 189.348
# 실제혈당 : [ 186.]예측혈당 : 193.763
# 실제혈당 : [ 185.]예측혈당 : 198.801
# 실제혈당 : [ 191.]예측혈당 : 202.482
# 실제혈당 : [ 192.]예측혈당 : 205.685
# 실제혈당 : [ 193.]예측혈당 : 209.144
# 실제혈당 : [ 198.]예측혈당 : 209.937
# 실제혈당 : [ 195.]예측혈당 : 192.256
# 실제혈당 : [ 193.]예측혈당 : 192.536
# 실제혈당 : [ 189.]예측혈당 : 183.606
# 실제혈당 : [ 189.]예측혈당 : 169.777
# 실제혈당 : [ 182.]예측혈당 : 182.817
# 실제혈당 : [ 179.]예측혈당 : 184.329
# 실제혈당 : [ 162.]예측혈당 : 187.941
# 실제혈당 : [ 156.]예측혈당 : 184.277
# 실제혈당 : [ 163.]예측혈당 : 184.902
# 실제혈당 : [ 168.]예측혈당 : 191.287
# 실제혈당 : [ 164.]예측혈당 : 189.442
# 실제혈당 : [ 168.]예측혈당 : 191.414
# 실제혈당 : [ 168.]예측혈당 : 196.29
# 실제혈당 : [ 169.]예측혈당 : 190.53
# 실제혈당 : [ 169.]예측혈당 : 191.041
# 실제혈당 : [ 172.]예측혈당 : 186.377
# 실제혈당 : [ 172.]예측혈당 : 188.429
# 실제혈당 : [ 172.]예측혈당 : 180.399
# 실제혈당 : [ 169.]예측혈당 : 180.627
# 실제혈당 : [ 169.]예측혈당 : 167.34
# 실제혈당 : [ 167.]예측혈당 : 166.985
# 실제혈당 : [ 165.]예측혈당 : 171.727
# 실제혈당 : [ 162.]예측혈당 : 174.013
# 실제혈당 : [ 161.]예측혈당 : 170.317
# 실제혈당 : [ 161.]예측혈당 : 174.474
# 실제혈당 : [ 162.]예측혈당 : 173.125
# 실제혈당 : [ 165.]예측혈당 : 174.373
# 실제혈당 : [ 168.]예측혈당 : 173.96
# 실제혈당 : [ 171.]예측혈당 : 176.575
# 실제혈당 : [ 173.]예측혈당 : 175.668
# 실제혈당 : [ 173.]예측혈당 : 175.99
# 실제혈당 : [ 171.]예측혈당 : 173.457
# 실제혈당 : [ 170.]예측혈당 : 174.291
# 실제혈당 : [ 169.]예측혈당 : 172.464
# 실제혈당 : [ 167.]예측혈당 : 171.534
# 실제혈당 : [ 166.]예측혈당 : 169.682
# 실제혈당 : [ 164.]예측혈당 : 169.515
# 실제혈당 : [ 162.]예측혈당 : 169.555
# 실제혈당 : [ 160.]예측혈당 : 170.222
# 실제혈당 : [ 159.]예측혈당 : 172.181
# 실제혈당 : [ 158.]예측혈당 : 173.859
# 실제혈당 : [ 158.]예측혈당 : 175.736
# 실제혈당 : [ 156.]예측혈당 : 176.782
# 실제혈당 : [ 155.]예측혈당 : 176.429
# 실제혈당 : [ 156.]예측혈당 : 174.905
# 실제혈당 : [ 158.]예측혈당 : 174.619
# 실제혈당 : [ 155.]예측혈당 : 173.914
# 실제혈당 : [ 152.]예측혈당 : 172.584
# 실제혈당 : [ 150.]예측혈당 : 172.236
# 실제혈당 : [ 148.]예측혈당 : 170.872
# 실제혈당 : [ 146.]예측혈당 : 169.864
# 실제혈당 : [ 144.]예측혈당 : 168.796
# 실제혈당 : [ 142.]예측혈당 : 168.426
# 실제혈당 : [ 139.]예측혈당 : 167.88
# 실제혈당 : [ 137.]예측혈당 : 168.018
# 실제혈당 : [ 137.]예측혈당 : 166.747
# 실제혈당 : [ 136.]예측혈당 : 166.463
# 실제혈당 : [ 136.]예측혈당 : 167.132
# 실제혈당 : [ 137.]예측혈당 : 168.207
# 실제혈당 : [ 137.]예측혈당 : 166.105
# 실제혈당 : [ 138.]예측혈당 : 164.905
# 실제혈당 : [ 138.]예측혈당 : 164.098
# 실제혈당 : [ 138.]예측혈당 : 163.242
# 실제혈당 : [ 138.]예측혈당 : 162.432
# 실제혈당 : [ 138.]예측혈당 : 161.649
# 실제혈당 : [ 134.]예측혈당 : 160.894
# 실제혈당 : [ 126.]예측혈당 : 159.748
# 실제혈당 : [ 117.]예측혈당 : 159.117
# 실제혈당 : [ 100.]예측혈당 : 159.21
# 실제혈당 : [ 81.]예측혈당 : 158.799
# 실제혈당 : [ 64.]예측혈당 : 158.858
# 실제혈당 : [ 58.]예측혈당 : 159.247
# 실제혈당 : [ 69.]예측혈당 : 159.189
# 실제혈당 : [ 85.]예측혈당 : 159.603
# 실제혈당 : [ 104.]예측혈당 : 159.539
# 실제혈당 : [ 106.]예측혈당 : 159.549
# 실제혈당 : [ 106.]예측혈당 : 159.548
# 실제혈당 : [ 106.]예측혈당 : 159.548
# 실제혈당 : [ 106.]예측혈당 : 157.983
# 실제혈당 : [ 106.]예측혈당 : 155.251
# 실제혈당 : [ 110.]예측혈당 : 151.849
# 실제혈당 : [ 109.]예측혈당 : 138.83
# 실제혈당 : [ 107.]예측혈당 : 105.148
# 실제혈당 : [ 107.]예측혈당 : 97.9695
# 실제혈당 : [ 105.]예측혈당 : 97.6812
# 실제혈당 : [ 103.]예측혈당 : 98.5281
# 실제혈당 : [ 103.]예측혈당 : 100.295
# 실제혈당 : [ 102.]예측혈당 : 104.731
# 실제혈당 : [ 102.]예측혈당 : 105.039
# 실제혈당 : [ 100.]예측혈당 : 105.04
# 실제혈당 : [ 98.]예측혈당 : 105.046
# 실제혈당 : [ 96.]예측혈당 : 105.141
# 실제혈당 : [ 96.]예측혈당 : 115.25
# 실제혈당 : [ 98.]예측혈당 : 121.182
# 실제혈당 : [ 100.]예측혈당 : 126.047
# 실제혈당 : [ 100.]예측혈당 : 129.38
# 실제혈당 : [ 105.]예측혈당 : 130.714
# 실제혈당 : [ 104.]예측혈당 : 126.451
# 실제혈당 : [ 98.]예측혈당 : 118.316
# 실제혈당 : [ 95.]예측혈당 : 111.202
# 실제혈당 : [ 93.]예측혈당 : 106.386
# 실제혈당 : [ 91.]예측혈당 : 104.673
# 실제혈당 : [ 89.]예측혈당 : 103.41
# 실제혈당 : [ 88.]예측혈당 : 102.7
# 실제혈당 : [ 86.]예측혈당 : 102.177
# 실제혈당 : [ 85.]예측혈당 : 102.204
# 실제혈당 : [ 86.]예측혈당 : 102.698
# 실제혈당 : [ 85.]예측혈당 : 103.204
# 실제혈당 : [ 94.]예측혈당 : 103.158
# 실제혈당 : [ 103.]예측혈당 : 104.827
# 실제혈당 : [ 103.]예측혈당 : 104.339
# 실제혈당 : [ 101.]예측혈당 : 102.566
# 실제혈당 : [ 103.]예측혈당 : 101.941
# 실제혈당 : [ 105.]예측혈당 : 101.53
# 실제혈당 : [ 109.]예측혈당 : 101.157
# 실제혈당 : [ 115.]예측혈당 : 100.8
# 실제혈당 : [ 121.]예측혈당 : 100.646
# 실제혈당 : [ 124.]예측혈당 : 100.331
# 실제혈당 : [ 125.]예측혈당 : 100.197
# 실제혈당 : [ 126.]예측혈당 : 100.357
# 실제혈당 : [ 124.]예측혈당 : 100.196
# 실제혈당 : [ 122.]예측혈당 : 101.86
# 실제혈당 : [ 123.]예측혈당 : 104.216
# 실제혈당 : [ 128.]예측혈당 : 104.003
# 실제혈당 : [ 132.]예측혈당 : 103.391
# 실제혈당 : [ 134.]예측혈당 : 104.086
# 실제혈당 : [ 135.]예측혈당 : 104.872
# 실제혈당 : [ 144.]예측혈당 : 107.288
# 실제혈당 : [ 148.]예측혈당 : 113.72
# 실제혈당 : [ 151.]예측혈당 : 143.636
# 실제혈당 : [ 149.]예측혈당 : 154.44
# 실제혈당 : [ 161.]예측혈당 : 155.068
# 실제혈당 : [ 165.]예측혈당 : 155.461
# 실제혈당 : [ 169.]예측혈당 : 154.678
# 실제혈당 : [ 170.]예측혈당 : 153.934
# 실제혈당 : [ 173.]예측혈당 : 154.346
# 실제혈당 : [ 175.]예측혈당 : 156.276
# 실제혈당 : [ 192.]예측혈당 : 157.626
# 실제혈당 : [ 202.]예측혈당 : 158.235
# 실제혈당 : [ 205.]예측혈당 : 158.543
# 실제혈당 : [ 212.]예측혈당 : 162.372
# 실제혈당 : [ 209.]예측혈당 : 163.586
# 실제혈당 : [ 209.]예측혈당 : 164.91
# 실제혈당 : [ 206.]예측혈당 : 163.568
# 실제혈당 : [ 220.]예측혈당 : 171.247
# 실제혈당 : [ 222.]예측혈당 : 171.833
# 실제혈당 : [ 228.]예측혈당 : 174.752
# 실제혈당 : [ 234.]예측혈당 : 174.587
# 실제혈당 : [ 237.]예측혈당 : 177.187
# 실제혈당 : [ 240.]예측혈당 : 178.029
# 실제혈당 : [ 240.]예측혈당 : 195.494
# 실제혈당 : [ 242.]예측혈당 : 198.823
# 실제혈당 : [ 241.]예측혈당 : 200.942
# 실제혈당 : [ 242.]예측혈당 : 208.905
# 실제혈당 : [ 242.]예측혈당 : 201.154
# 실제혈당 : [ 241.]예측혈당 : 205.481
# 실제혈당 : [ 238.]예측혈당 : 199.259
# 실제혈당 : [ 232.]예측혈당 : 220.207
# 실제혈당 : [ 230.]예측혈당 : 211.396
# 실제혈당 : [ 226.]예측혈당 : 223.66
# 실제혈당 : [ 225.]예측혈당 : 224.829
# 실제혈당 : [ 218.]예측혈당 : 227.937
# 실제혈당 : [ 213.]예측혈당 : 230.069
# 실제혈당 : [ 207.]예측혈당 : 228.587
# 실제혈당 : [ 203.]예측혈당 : 231.685
# 실제혈당 : [ 196.]예측혈당 : 228.788
# 실제혈당 : [ 194.]예측혈당 : 231.341
# 실제혈당 : [ 194.]예측혈당 : 230.018
# 실제혈당 : [ 192.]예측혈당 : 229.425
# 실제혈당 : [ 190.]예측혈당 : 226.058
# 실제혈당 : [ 188.]예측혈당 : 220.216
# 실제혈당 : [ 187.]예측혈당 : 220.802
# 실제혈당 : [ 186.]예측혈당 : 215.311
# 실제혈당 : [ 185.]예측혈당 : 216.968
# 실제혈당 : [ 181.]예측혈당 : 207.038
# 실제혈당 : [ 181.]예측혈당 : 206.008
# 실제혈당 : [ 179.]예측혈당 : 199.187
# 실제혈당 : [ 178.]예측혈당 : 197.844
# 실제혈당 : [ 173.]예측혈당 : 190.413
# 실제혈당 : [ 177.]예측혈당 : 191.684
# 실제혈당 : [ 174.]예측혈당 : 191.207
# 실제혈당 : [ 173.]예측혈당 : 189.265
# 실제혈당 : [ 181.]예측혈당 : 188.031
# 실제혈당 : [ 188.]예측혈당 : 186.472
# 실제혈당 : [ 187.]예측혈당 : 186.156
# 실제혈당 : [ 187.]예측혈당 : 185.24
# 실제혈당 : [ 189.]예측혈당 : 184.575
# 실제혈당 : [ 200.]예측혈당 : 180.89
# 실제혈당 : [ 212.]예측혈당 : 182.356
# 실제혈당 : [ 218.]예측혈당 : 179.848
# 실제혈당 : [ 240.]예측혈당 : 179.869
# 실제혈당 : [ 257.]예측혈당 : 175.446
# 실제혈당 : [ 262.]예측혈당 : 180.603
# 실제혈당 : [ 273.]예측혈당 : 175.999
# 실제혈당 : [ 287.]예측혈당 : 176.766
# 실제혈당 : [ 292.]예측혈당 : 183.948
# 실제혈당 : [ 305.]예측혈당 : 188.164
# 실제혈당 : [ 304.]예측혈당 : 185.294
# 실제혈당 : [ 305.]예측혈당 : 186.584
# 실제혈당 : [ 322.]예측혈당 : 188.236
# 실제혈당 : [ 340.]예측혈당 : 200.375
# 실제혈당 : [ 359.]예측혈당 : 209.19
# 실제혈당 : [ 364.]예측혈당 : 212.219
# 실제혈당 : [ 369.]예측혈당 : 237.892
# 실제혈당 : [ 371.]예측혈당 : 244.446
# 실제혈당 : [ 375.]예측혈당 : 246.505
# 실제혈당 : [ 374.]예측혈당 : 254.856
# 실제혈당 : [ 377.]예측혈당 : 261.506
# 실제혈당 : [ 375.]예측혈당 : 262.65
# 실제혈당 : [ 371.]예측혈당 : 267.969
# 실제혈당 : [ 366.]예측혈당 : 266.798
# 실제혈당 : [ 367.]예측혈당 : 267.356
# 실제혈당 : [ 367.]예측혈당 : 271.949
# 실제혈당 : [ 367.]예측혈당 : 274.334
# 실제혈당 : [ 375.]예측혈당 : 275.716
# 실제혈당 : [ 367.]예측혈당 : 275.929
# 실제혈당 : [ 358.]예측혈당 : 276.125
# 실제혈당 : [ 357.]예측혈당 : 276.192
# 실제혈당 : [ 347.]예측혈당 : 276.315
# 실제혈당 : [ 342.]예측혈당 : 276.284
# 실제혈당 : [ 349.]예측혈당 : 276.369
# 실제혈당 : [ 350.]예측혈당 : 276.313
# 실제혈당 : [ 355.]예측혈당 : 276.189
# 실제혈당 : [ 339.]예측혈당 : 276.005
# 실제혈당 : [ 347.]예측혈당 : 276.049
# 실제혈당 : [ 345.]예측혈당 : 276.048
# 실제혈당 : [ 352.]예측혈당 : 276.048
# 실제혈당 : [ 355.]예측혈당 : 276.317
# 실제혈당 : [ 351.]예측혈당 : 276.043
# 실제혈당 : [ 345.]예측혈당 : 275.622
# 실제혈당 : [ 331.]예측혈당 : 275.575
# 실제혈당 : [ 331.]예측혈당 : 274.862
# 실제혈당 : [ 317.]예측혈당 : 274.416
# 실제혈당 : [ 318.]예측혈당 : 275.067
# 실제혈당 : [ 305.]예측혈당 : 275.123
# 실제혈당 : [ 300.]예측혈당 : 275.467
# 실제혈당 : [ 310.]예측혈당 : 274.056
# 실제혈당 : [ 314.]예측혈당 : 274.917
# 실제혈당 : [ 318.]예측혈당 : 274.708
# 실제혈당 : [ 303.]예측혈당 : 275.28
# 실제혈당 : [ 305.]예측혈당 : 275.463
# 실제혈당 : [ 309.]예측혈당 : 275.186
# 실제혈당 : [ 310.]예측혈당 : 274.698
# 실제혈당 : [ 298.]예측혈당 : 273.002
# 실제혈당 : [ 282.]예측혈당 : 273.113
# 실제혈당 : [ 279.]예측혈당 : 270.256
# 실제혈당 : [ 293.]예측혈당 : 270.807
# 실제혈당 : [ 293.]예측혈당 : 266.728
# 실제혈당 : [ 292.]예측혈당 : 265.386
# 실제혈당 : [ 285.]예측혈당 : 269.205
# 실제혈당 : [ 280.]예측혈당 : 269.892
# 실제혈당 : [ 273.]예측혈당 : 270.844
# 실제혈당 : [ 262.]예측혈당 : 265.924
# 실제혈당 : [ 258.]예측혈당 : 267.489
# 실제혈당 : [ 253.]예측혈당 : 268.623
# 실제혈당 : [ 248.]예측혈당 : 268.789
# 실제혈당 : [ 240.]예측혈당 : 264.093
# 실제혈당 : [ 242.]예측혈당 : 255.789
# 실제혈당 : [ 244.]예측혈당 : 256.134
# 실제혈당 : [ 238.]예측혈당 : 264.236
# 실제혈당 : [ 242.]예측혈당 : 262.556
# 실제혈당 : [ 244.]예측혈당 : 262.4
# 실제혈당 : [ 240.]예측혈당 : 258.326
# 실제혈당 : [ 246.]예측혈당 : 256.084
# 실제혈당 : [ 240.]예측혈당 : 251.408
# 실제혈당 : [ 248.]예측혈당 : 243.05
# 실제혈당 : [ 245.]예측혈당 : 242.541
# 실제혈당 : [ 242.]예측혈당 : 237.408
# 실제혈당 : [ 239.]예측혈당 : 234.144
# 실제혈당 : [ 223.]예측혈당 : 226.106
# 실제혈당 : [ 232.]예측혈당 : 232.491
# 실제혈당 : [ 228.]예측혈당 : 231.685
# 실제혈당 : [ 221.]예측혈당 : 224.726
# 실제혈당 : [ 217.]예측혈당 : 233.118
# 실제혈당 : [ 213.]예측혈당 : 231.343
# 실제혈당 : [ 209.]예측혈당 : 227.537
# 실제혈당 : [ 206.]예측혈당 : 236.485
# 실제혈당 : [ 197.]예측혈당 : 224.785
# 실제혈당 : [ 188.]예측혈당 : 239.995
# 실제혈당 : [ 184.]예측혈당 : 229.219
# 실제혈당 : [ 178.]예측혈당 : 230.989
# 실제혈당 : [ 176.]예측혈당 : 226.527
# 실제혈당 : [ 164.]예측혈당 : 208.306
# 실제혈당 : [ 166.]예측혈당 : 229.591
# 실제혈당 : [ 156.]예측혈당 : 213.063
# 실제혈당 : [ 153.]예측혈당 : 212.977
# 실제혈당 : [ 149.]예측혈당 : 207.899
# 실제혈당 : [ 141.]예측혈당 : 205.507
# 실제혈당 : [ 142.]예측혈당 : 202.187
# 실제혈당 : [ 143.]예측혈당 : 199.926
# 실제혈당 : [ 148.]예측혈당 : 190.507
# 실제혈당 : [ 151.]예측혈당 : 185.198
# 실제혈당 : [ 154.]예측혈당 : 183.427
# 실제혈당 : [ 156.]예측혈당 : 178.443
# 실제혈당 : [ 159.]예측혈당 : 178.503
# 실제혈당 : [ 164.]예측혈당 : 169.109
# 실제혈당 : [ 168.]예측혈당 : 173.351
# 실제혈당 : [ 173.]예측혈당 : 165.505
# 실제혈당 : [ 178.]예측혈당 : 165.622
# 실제혈당 : [ 181.]예측혈당 : 163.441
# 실제혈당 : [ 184.]예측혈당 : 160.171
# 실제혈당 : [ 187.]예측혈당 : 161.156
# 실제혈당 : [ 192.]예측혈당 : 161.425
# 실제혈당 : [ 191.]예측혈당 : 163.789
# 실제혈당 : [ 189.]예측혈당 : 164.866
# 실제혈당 : [ 190.]예측혈당 : 166.315
# 실제혈당 : [ 190.]예측혈당 : 167.155
# 실제혈당 : [ 192.]예측혈당 : 168.839
# 실제혈당 : [ 194.]예측혈당 : 171.843
# 실제혈당 : [ 197.]예측혈당 : 173.953
# 실제혈당 : [ 197.]예측혈당 : 177.399
# 실제혈당 : [ 193.]예측혈당 : 180.665
# 실제혈당 : [ 193.]예측혈당 : 182.282
# 실제혈당 : [ 193.]예측혈당 : 184.67
# 실제혈당 : [ 191.]예측혈당 : 186.828
# 실제혈당 : [ 195.]예측혈당 : 191.415
# 실제혈당 : [ 196.]예측혈당 : 188.249
# 실제혈당 : [ 198.]예측혈당 : 187.557
# 실제혈당 : [ 199.]예측혈당 : 188.981
# 실제혈당 : [ 209.]예측혈당 : 188.334
# 실제혈당 : [ 205.]예측혈당 : 190.828
# 실제혈당 : [ 204.]예측혈당 : 191.871
# 실제혈당 : [ 207.]예측혈당 : 194.883
# 실제혈당 : [ 210.]예측혈당 : 193.473
# 실제혈당 : [ 209.]예측혈당 : 189.622
# 실제혈당 : [ 211.]예측혈당 : 191.436
# 실제혈당 : [ 212.]예측혈당 : 190.556
# 실제혈당 : [ 211.]예측혈당 : 188.706
# 실제혈당 : [ 212.]예측혈당 : 194.05
# 실제혈당 : [ 212.]예측혈당 : 192.622
# 실제혈당 : [ 211.]예측혈당 : 195.731
# 실제혈당 : [ 208.]예측혈당 : 195.405
# 실제혈당 : [ 205.]예측혈당 : 208.045
# 실제혈당 : [ 203.]예측혈당 : 196.568
# 실제혈당 : [ 202.]예측혈당 : 201.186
# 실제혈당 : [ 200.]예측혈당 : 202.546
# 실제혈당 : [ 198.]예측혈당 : 205.609
# 실제혈당 : [ 196.]예측혈당 : 202.73
# 실제혈당 : [ 194.]예측혈당 : 206.553
# 실제혈당 : [ 191.]예측혈당 : 205.915
# 실제혈당 : [ 190.]예측혈당 : 205.025
# 실제혈당 : [ 188.]예측혈당 : 206.693
# 실제혈당 : [ 185.]예측혈당 : 205.722
# 실제혈당 : [ 184.]예측혈당 : 204.998
# 실제혈당 : [ 182.]예측혈당 : 201.544
# 실제혈당 : [ 179.]예측혈당 : 199.583
# 실제혈당 : [ 179.]예측혈당 : 198.151
# 실제혈당 : [ 177.]예측혈당 : 197.618
# 실제혈당 : [ 176.]예측혈당 : 195.467
# 실제혈당 : [ 167.]예측혈당 : 194.172
# 실제혈당 : [ 163.]예측혈당 : 192.52
# 실제혈당 : [ 161.]예측혈당 : 191.058
# 실제혈당 : [ 160.]예측혈당 : 188.408
# 실제혈당 : [ 159.]예측혈당 : 188.502
# 실제혈당 : [ 159.]예측혈당 : 186.306
# 실제혈당 : [ 161.]예측혈당 : 184.138
# 실제혈당 : [ 164.]예측혈당 : 184.022
# 실제혈당 : [ 165.]예측혈당 : 182.066
# 실제혈당 : [ 165.]예측혈당 : 179.972
# 실제혈당 : [ 164.]예측혈당 : 180.763
# 실제혈당 : [ 164.]예측혈당 : 178.592
# 실제혈당 : [ 163.]예측혈당 : 178.494
# 실제혈당 : [ 162.]예측혈당 : 171.225
# 실제혈당 : [ 162.]예측혈당 : 170.504
# 실제혈당 : [ 161.]예측혈당 : 169.312
# 실제혈당 : [ 160.]예측혈당 : 168.954
# 실제혈당 : [ 162.]예측혈당 : 168.383
# 실제혈당 : [ 162.]예측혈당 : 168.527
# 실제혈당 : [ 163.]예측혈당 : 169.818
# 실제혈당 : [ 163.]예측혈당 : 171.559
# 실제혈당 : [ 163.]예측혈당 : 171.763
# 실제혈당 : [ 164.]예측혈당 : 171.706
# 실제혈당 : [ 168.]예측혈당 : 171.005
# 실제혈당 : [ 167.]예측혈당 : 171.22
# 실제혈당 : [ 168.]예측혈당 : 170.447
# 실제혈당 : [ 169.]예측혈당 : 169.973
# 실제혈당 : [ 173.]예측혈당 : 170.106
# 실제혈당 : [ 176.]예측혈당 : 169.384
# 실제혈당 : [ 180.]예측혈당 : 168.916
# 실제혈당 : [ 184.]예측혈당 : 170.404
# 실제혈당 : [ 187.]예측혈당 : 169.973
# 실제혈당 : [ 190.]예측혈당 : 170.798
# 실제혈당 : [ 192.]예측혈당 : 170.556
# 실제혈당 : [ 194.]예측혈당 : 170.63
# 실제혈당 : [ 196.]예측혈당 : 171.326
# 실제혈당 : [ 195.]예측혈당 : 174.149
# 실제혈당 : [ 192.]예측혈당 : 172.466
# 실제혈당 : [ 190.]예측혈당 : 173.783
# 실제혈당 : [ 188.]예측혈당 : 174.147
# 실제혈당 : [ 186.]예측혈당 : 177.372
# 실제혈당 : [ 181.]예측혈당 : 178.858
# 실제혈당 : [ 177.]예측혈당 : 182.055
# 실제혈당 : [ 175.]예측혈당 : 184.76
# 실제혈당 : [ 175.]예측혈당 : 186.77
# 실제혈당 : [ 176.]예측혈당 : 189.183
# 실제혈당 : [ 179.]예측혈당 : 190.357
# 실제혈당 : [ 179.]예측혈당 : 192.141
# 실제혈당 : [ 183.]예측혈당 : 193.645
# 실제혈당 : [ 185.]예측혈당 : 191.8
# 실제혈당 : [ 185.]예측혈당 : 189.306
# 실제혈당 : [ 191.]예측혈당 : 188.226
# 실제혈당 : [ 193.]예측혈당 : 186.524
# 실제혈당 : [ 192.]예측혈당 : 185.118
# 실제혈당 : [ 187.]예측혈당 : 180.689
# 실제혈당 : [ 188.]예측혈당 : 178.66
# 실제혈당 : [ 195.]예측혈당 : 177.603
# 실제혈당 : [ 196.]예측혈당 : 177.959
# 실제혈당 : [ 194.]예측혈당 : 178.696
# 실제혈당 : [ 193.]예측혈당 : 181.189
# 실제혈당 : [ 193.]예측혈당 : 180.217
# 실제혈당 : [ 185.]예측혈당 : 184.557
# 실제혈당 : [ 182.]예측혈당 : 184.785
# 실제혈당 : [ 185.]예측혈당 : 184.728
# 실제혈당 : [ 184.]예측혈당 : 191.278
# 실제혈당 : [ 194.]예측혈당 : 190.496
# 실제혈당 : [ 197.]예측혈당 : 189.814
# 실제혈당 : [ 205.]예측혈당 : 184.785
# 실제혈당 : [ 208.]예측혈당 : 188.049
# 실제혈당 : [ 207.]예측혈당 : 194.433
# 실제혈당 : [ 213.]예측혈당 : 192.453
# 실제혈당 : [ 221.]예측혈당 : 191.11
# 실제혈당 : [ 232.]예측혈당 : 190.652
# 실제혈당 : [ 240.]예측혈당 : 190.952
# 실제혈당 : [ 228.]예측혈당 : 182.364
# 실제혈당 : [ 237.]예측혈당 : 182.812
# 실제혈당 : [ 239.]예측혈당 : 185.608
# 실제혈당 : [ 231.]예측혈당 : 183.378
# 실제혈당 : [ 249.]예측혈당 : 195.363
# 실제혈당 : [ 253.]예측혈당 : 193.029
# 실제혈당 : [ 261.]예측혈당 : 204.086
# 실제혈당 : [ 264.]예측혈당 : 202.208
# 실제혈당 : [ 267.]예측혈당 : 202.056
# 실제혈당 : [ 255.]예측혈당 : 209.945
# 실제혈당 : [ 227.]예측혈당 : 215.918
# 실제혈당 : [ 205.]예측혈당 : 226.701
# 실제혈당 : [ 200.]예측혈당 : 230.733
# 실제혈당 : [ 216.]예측혈당 : 213.36
# 실제혈당 : [ 212.]예측혈당 : 233.724
# 실제혈당 : [ 214.]예측혈당 : 225.624
# 실제혈당 : [ 197.]예측혈당 : 219.595
# 실제혈당 : [ 201.]예측혈당 : 243.383
# 실제혈당 : [ 197.]예측혈당 : 236.866
# 실제혈당 : [ 207.]예측혈당 : 247.996
# 실제혈당 : [ 219.]예측혈당 : 246.364
# 실제혈당 : [ 226.]예측혈당 : 249.7
# 실제혈당 : [ 227.]예측혈당 : 236.335
# 실제혈당 : [ 220.]예측혈당 : 208.34
# 실제혈당 : [ 202.]예측혈당 : 195.555
# 실제혈당 : [ 221.]예측혈당 : 195.919
# 실제혈당 : [ 219.]예측혈당 : 215.897
# 실제혈당 : [ 224.]예측혈당 : 199.882
# 실제혈당 : [ 233.]예측혈당 : 210.841
# 실제혈당 : [ 234.]예측혈당 : 185.588
# 실제혈당 : [ 227.]예측혈당 : 202.979
# 실제혈당 : [ 210.]예측혈당 : 189.656
# 실제혈당 : [ 211.]예측혈당 : 208.173
# 실제혈당 : [ 205.]예측혈당 : 213.719
# 실제혈당 : [ 207.]예측혈당 : 219.766
# 실제혈당 : [ 209.]예측혈당 : 218.258
# 실제혈당 : [ 209.]예측혈당 : 210.013
# 실제혈당 : [ 198.]예측혈당 : 192.223
# 실제혈당 : [ 194.]예측혈당 : 225.069
# 실제혈당 : [ 173.]예측혈당 : 204.527
# 실제혈당 : [ 177.]예측혈당 : 221.831
# 실제혈당 : [ 173.]예측혈당 : 223.994
# 실제혈당 : [ 174.]예측혈당 : 224.323
# 실제혈당 : [ 173.]예측혈당 : 215.729
# 실제혈당 : [ 185.]예측혈당 : 198.173
# 실제혈당 : [ 180.]예측혈당 : 208.717
# 실제혈당 : [ 175.]예측혈당 : 195.615
# 실제혈당 : [ 162.]예측혈당 : 204.627
# 실제혈당 : [ 148.]예측혈당 : 202.335
# 실제혈당 : [ 141.]예측혈당 : 203.73
# 실제혈당 : [ 138.]예측혈당 : 190.279
# 실제혈당 : [ 140.]예측혈당 : 192.071
# 실제혈당 : [ 134.]예측혈당 : 171.613
# 실제혈당 : [ 136.]예측혈당 : 182.169
# 실제혈당 : [ 131.]예측혈당 : 174.59
# 실제혈당 : [ 128.]예측혈당 : 178.093
# 실제혈당 : [ 120.]예측혈당 : 175.969
# 실제혈당 : [ 117.]예측혈당 : 188.459
# 실제혈당 : [ 121.]예측혈당 : 178.362
# 실제혈당 : [ 121.]예측혈당 : 177.671
# 실제혈당 : [ 113.]예측혈당 : 168.081
# 실제혈당 : [ 118.]예측혈당 : 162.513
# 실제혈당 : [ 123.]예측혈당 : 160.348
# 실제혈당 : [ 133.]예측혈당 : 159.435
# 실제혈당 : [ 137.]예측혈당 : 160.405
# 실제혈당 : [ 133.]예측혈당 : 157.869
# 실제혈당 : [ 118.]예측혈당 : 158.995
# 실제혈당 : [ 101.]예측혈당 : 156.942
# 실제혈당 : [ 94.]예측혈당 : 156.079
# 실제혈당 : [ 113.]예측혈당 : 153.097
# 실제혈당 : [ 123.]예측혈당 : 151.748
# 실제혈당 : [ 139.]예측혈당 : 153.443
# 실제혈당 : [ 151.]예측혈당 : 153.444
# 실제혈당 : [ 142.]예측혈당 : 149.59
# 실제혈당 : [ 150.]예측혈당 : 151.753
# 실제혈당 : [ 139.]예측혈당 : 154.213
# 실제혈당 : [ 146.]예측혈당 : 158.23
# 실제혈당 : [ 140.]예측혈당 : 159.332
# 실제혈당 : [ 142.]예측혈당 : 157.635
# 실제혈당 : [ 142.]예측혈당 : 152.215
# 실제혈당 : [ 148.]예측혈당 : 140.248
# 실제혈당 : [ 147.]예측혈당 : 119.1
# 실제혈당 : [ 157.]예측혈당 : 119.008
# 실제혈당 : [ 158.]예측혈당 : 128.219
# 실제혈당 : [ 158.]예측혈당 : 160.605
# 실제혈당 : [ 166.]예측혈당 : 165.392
# 실제혈당 : [ 167.]예측혈당 : 160.229
# 실제혈당 : [ 171.]예측혈당 : 165.122
# 실제혈당 : [ 176.]예측혈당 : 159.091
# 실제혈당 : [ 180.]예측혈당 : 163.254
# loop end
# 1번째 환자 rmse : 28.3891461289
# 2번째 환자 rmse : 26.749721577
# 3번째 환자 rmse : 29.8432350625
# 전체 평균 rmse : 28.2440859002
