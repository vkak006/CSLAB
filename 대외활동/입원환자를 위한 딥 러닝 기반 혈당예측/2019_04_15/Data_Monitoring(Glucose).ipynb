# %%
import csv
import matplotlib.pyplot as plt

line_counter = 0
header = []
customer_list = []
a=[]
b=[]
c=[]
d=[]
e=[]
g=[]

num = 4
with open('prediction_result(A1c)/predicttion_sugarblood' + str(num) + '.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        a.append(float(y))
        b.append(float(y_d))

with open('prediction_result(Just)/predicttion_sugarblood.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        c.append(float(y))
        d.append(float(y_d))     
        
with open('prediction_result(HbA1c+DM)/predicttion_sugarblood'+ str(num) +'.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        e.append(float(y))
        g.append(float(y_d))

# %%
#plt.plot(a,color="red")
plt.plot(b,color="blue")
plt.title("실제 환자 혈당 데이터")
plt.show()

# %%
#plt.plot(a,color="red")
plt.plot(d,color="blue")
plt.title("Test case - DM")
plt.show()

# %%
plt.plot(e,color="red")
plt.plot(g,color="blue")
plt.title("Test case - HbA1c + DM")
plt.show()
