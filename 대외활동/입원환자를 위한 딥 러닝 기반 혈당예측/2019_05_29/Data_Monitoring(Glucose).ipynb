# %%
import csv
import matplotlib.pyplot as plt

line_counter = 0
PH = 30
header = []
customer_list = []
a=[]
b=[]
c=[]
d=[]
e=[]
g=[]

num = 4
with open('Capstone_test_result/Just_LSTM/PH'+ str(PH) +'/predicttion_sugarblood' + str(num) + '.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        a.append(float(y))
        b.append(float(y_d))

with open('Capstone_test_result/Bi-LSTM/PH'+ str(PH) +'/predicttion_sugarblood'+ str(num) +'.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        c.append(float(y))
        d.append(float(y_d))

# %%
plt.plot(a,color="red")
plt.plot(b,color="blue")
plt.title("Test case - LSTM")
plt.show()

# %%
plt.plot(c,color="red")
plt.plot(d,color="blue")
plt.title("Test case - Bi-LSTM")
plt.show()

# %%
plt.plot(e,color="red")
plt.plot(g,color="blue")
plt.title("Test case - HbA1c + DM")
plt.show()
