# %%
import csv
import matplotlib.pyplot as plt

line_counter = 0
header = []
customer_list = []
a=[]
b=[]
with open('prediction_result/predicttion_sugarblood0.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d = data.split(',')
        a.append(float(y))
        b.append(float(y_d))

plt.plot(a,color="red")
plt.plot(b,color="blue")
plt.title("data_pre")
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

line_counter = 0
header = []
customer_list = []
a=[]
b=[]
c=[]
with open('predicttion_sugarblood_4.csv')as f:
    while 1:
        data = f.readline()
         # data에 파일을 한 줄씩 불러옴
        if not data:break
        y,y_d,m = data.split(',')
        a.append(float(y))
        b.append(float(y_d))
        c.append(float(m))

plt.plot(a,color="red")
plt.plot(b,color="blue")
plt.plot(c,color="green")
plt.title("data_pre")
plt.show()
